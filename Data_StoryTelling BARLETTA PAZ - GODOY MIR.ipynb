# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import sklearn.metrics as metrics


# Librerías para importar/exportar el modelo
import json
import pickle

from scipy import stats
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import chi2, mutual_info_classif, mutual_info_regression
from sklearn.preprocessing import PowerTransformer, MinMaxScaler
from sklearn.neighbors import LocalOutlierFactor
from sklearn.model_selection import train_test_split, ShuffleSplit
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# Preprocesado y modelado
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import scale
import statsmodels.api as sm

# %%
# !pip install google-api-python-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install twython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from twython import Twython, TwythonError
import requests
import pandas as pd

# %%
access_token= "1598351571519242245-rIy1Y1sHkmsvZYGPKPcyxAECqxXCWB"
access_token_secret= "eA3urMxzNcbOhv2x2s5qUXmUtjfCqPCBOTkaodW2ObbAX"
consumer_key= "MTYtQjNBeldGTGZuUUZyUzEydVU6MTpjaQ"
consumer_secret= "P1SZ9ByFL78yyuqU8zwGDqXJ9TrVQGyGMsr16e-Ytnyvid0tpu"

twitter = Twython(
    consumer_key,
    consumer_secret,
    access_token,
    access_token_secret)

# %%
twitter.verify_credentials()
# Out:
# ---------------------------------------------------------------------------
# TwythonAuthError                          Traceback (most recent call last)
# <ipython-input-6-491a6882d997> in <module>
# ----> 1 twitter.verify_credentials()
#
# /usr/local/lib/python3.8/dist-packages/twython/endpoints.py in verify_credentials(self, **params)
#     498
#     499         """
# --> 500         return self.get('account/verify_credentials', params=params)
#     501
#     502     def update_account_settings(self, **params):
#
# /usr/local/lib/python3.8/dist-packages/twython/api.py in get(self, endpoint, params, version)
#     277     def get(self, endpoint, params=None, version='1.1'):
#     278         """Shortcut for GET requests via :class:`request`"""
# --> 279         return self.request(endpoint, params=params, version=version)
#     280
#     281     def post(self, endpoint, params=None, version='1.1', json_encoded=False):
#
# ...

# %%
search_results = twitter.search(count=100, q='wine')
# Out:
# ---------------------------------------------------------------------------
# TwythonAuthError                          Traceback (most recent call last)
# <ipython-input-7-dd0fb90f59c4> in <module>
# ----> 1 search_results = twitter.search(count=100, q='wine')
#
# /usr/local/lib/python3.8/dist-packages/twython/endpoints.py in search(self, **params)
#     291
#     292         """
# --> 293         return self.get('search/tweets', params=params)
#     294     search.iter_mode = 'id'
#     295     search.iter_key = 'statuses'
#
# /usr/local/lib/python3.8/dist-packages/twython/api.py in get(self, endpoint, params, version)
#     277     def get(self, endpoint, params=None, version='1.1'):
#     278         """Shortcut for GET requests via :class:`request`"""
# --> 279         return self.request(endpoint, params=params, version=version)
#     280
#     281     def post(self, endpoint, params=None, version='1.1', json_encoded=False):
#
# ...

# %%
search_results
